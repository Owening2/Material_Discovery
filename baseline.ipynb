# %%
from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd
import re 
import shutil
import os

# %%
train = pd.read_csv("data/train_set.ReorgE.csv")
train.columns = ['index', 'SMILES', 'Reorg_g', 'Reorg_ex']

train.head()
# Out:
#      index                                             SMILES   Reorg_g  \
# 0  train_0  CC[C@H]1CCCCN1C(=O)[C@@H](C)OC(=O)c1c(C)oc(-n2...  0.631486
# 1  train_1                     O[C@@H](CNC1CC1)CN1CCc2sccc2C1  0.825901
# 2  train_2                          N#CCCNC(=O)[C@@]1(O)CCSC1  1.463943
# 3  train_3        COC[C@H]1CN(c2ccc(OCC[C@@H](C)O)cc2)C(=O)O1  0.166669
# 4  train_4          N#Cc1c(-c2ccccc2OCC(N)=O)[nH]c(C(N)=O)c1N  0.313820
#
#    Reorg_ex
# 0  0.535060
# 1  1.116781
# 2  0.964848
# 3  0.161458
# 4  0.338862

# %%
if os.path.isdir("ex_file"):
    pass
else:
    os.mkdir("ex_file")
    
if os.path.isdir("g_file"):
    pass
else:
    os.mkdir("g_file")
    
train_mol = sorted(glob("./data/mol_files/train_set/*.mol"))
print(train_mol)

for i in tqdm(train_mol):
    result = []
    tmp = open(i, 'r').read().split('\n')
    for j in tmp:
        tmp_ = re.sub(' +', ' ', j.lstrip()).split(' ')
        if len(tmp_) > 11:
            result.append(tmp_)
            
    file_name = i.split('\\')[-1].split('.')[0]
    
    if "ex" in file_name:
        pd.DataFrame(result).to_csv(f"./ex_file/{file_name}" + ".csv", index = False)
    elif "g" in file_name:
        pd.DataFrame(result).to_csv(f"./g_file/{file_name}" + ".csv", index = False)
# Out:
# ['./data/mol_files/train_set/train_0_ex.mol', './data/mol_files/train_set/train_0_g.mol', './data/mol_files/train_set/train_10000_ex.mol', './data/mol_files/train_set/train_10000_g.mol', './data/mol_files/train_set/train_10001_ex.mol', './data/mol_files/train_set/train_10001_g.mol', './data/mol_files/train_set/train_10002_ex.mol', './data/mol_files/train_set/train_10002_g.mol', './data/mol_files/train_set/train_10003_ex.mol', './data/mol_files/train_set/train_10003_g.mol', './data/mol_files/train_set/train_10004_ex.mol', './data/mol_files/train_set/train_10004_g.mol', './data/mol_files/train_set/train_10005_ex.mol', './data/mol_files/train_set/train_10005_g.mol', './data/mol_files/train_set/train_10006_ex.mol', './data/mol_files/train_set/train_10006_g.mol', './data/mol_files/train_set/train_10007_ex.mol', './data/mol_files/train_set/train_10007_g.mol', './data/mol_files/train_set/train_10008_ex.mol', './data/mol_files/train_set/train_10008_g.mol', './data/mol_files/train_set/train_10009_ex.mol', './data/mol_files/train_set/train_10009_g.mol', './data/mol_files/train_set/train_1000_ex.mol', './data/mol_files/train_set/train_1000_g.mol', './data/mol_files/train_set/train_10010_ex.mol', './data/mol_files/train_set/train_10010_g.mol', './data/mol_files/train_set/train_10011_ex.mol', './data/mol_files/train_set/train_10011_g.mol', './data/mol_files/train_set/train_10012_ex.mol', './data/mol_files/train_set/train_10012_g.mol', './data/mol_files/train_set/train_10013_ex.mol', './data/mol_files/train_set/train_10013_g.mol', './data/mol_files/train_set/train_10014_ex.mol', './data/mol_files/train_set/train_10014_g.mol', './data/mol_files/train_set/train_10015_ex.mol', './data/mol_files/train_set/train_10015_g.mol', './data/mol_files/train_set/train_10016_ex.mol', './data/mol_files/train_set/train_10016_g.mol', './data/mol_files/train_set/train_10017_ex.mol', './data/mol_files/train_set/train_10017_g.mol', './data/mol_files/train_set/train_10018_ex.mol', './data/mol_files/train_set/train_10018_g.mol', './data/mol_files/train_set/train_10019_ex.mol', './data/mol_files/train_set/train_10019_g.mol', './data/mol_files/train_set/train_1001_ex.mol', './data/mol_files/train_set/train_1001_g.mol', './data/mol_files/train_set/train_10020_ex.mol', './data/mol_files/train_set/train_10020_g.mol', './data/mol_files/train_set/train_10021_ex.mol', './data/mol_files/train_set/train_10021_g.mol', './data/mol_files/train_set/train_10022_ex.mol', './data/mol_files/train_set/train_10022_g.mol', './data/mol_files/train_set/train_10023_ex.mol', './data/mol_files/train_set/train_10023_g.mol', './data/mol_files/train_set/train_10024_ex.mol', './data/mol_files/train_set/train_10024_g.mol', './data/mol_files/train_set/train_10025_ex.mol', './data/mol_files/train_set/train_10025_g.mol', './data/mol_files/train_set/train_10026_ex.mol', './data/mol_files/train_set/train_10026_g.mol', './data/mol_files/train_set/train_10027_ex.mol', './data/mol_files/train_set/train_10027_g.mol', './data/mol_files/train_set/train_10028_ex.mol', './data/mol_files/train_set/train_10028_g.mol', './data/mol_files/train_set/train_10029_ex.mol', './data/mol_files/train_set/train_10029_g.mol', './data/mol_files/train_set/train_1002_ex.mol', './data/mol_files/train_set/train_1002_g.mol', './data/mol_files/train_set/train_10030_ex.mol', './data/mol_files/train_set/train_10030_g.mol', './data/mol_files/train_set/train_10031_ex.mol', './data/mol_files/train_set/train_10031_g.mol', './data/mol_files/train_set/train_10032_ex.mol', './data/mol_files/train_set/train_10032_g.mol', './data/mol_files/train_set/train_10033_ex.mol', './data/mol_files/train_set/train_10033_g.mol', './data/mol_files/train_set/train_10034_ex.mol', './data/mol_files/train_set/train_10034_g.mol', './data/mol_files/train_set/train_10035_ex.mol', './data/mol_files/train_set/train_10035_g.mol', './data/mol_files/train_set/train_10036_ex.mol', './data/mol_files/train_set/train_10036_g.mol', './data/mol_files/train_set/train_10 ...
# 100%|██████████| 36314/36314 [00:08<00:00, 4285.69it/s]

# %%
max_len = 0
error = []
g_data, ex_data = [], []
mol = []

for i in tqdm(train[train.columns[0]]):
    tmp_g = pd.read_csv(f"g_file/{i}" + '_g.csv')
    
    if len(tmp_g) >= max_len:
        max_len = len(tmp_g)
    
    for j in tmp_g["3"]:
        mol.append(j)
# Out:
#   0%|          | 0/18157 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/dataly/Desktop/Yeongyu/dacon/SamsungAI/baseline.ipynb 셀 5 in <module>
#       <a href='vscode-notebook-cell:/Users/dataly/Desktop/Yeongyu/dacon/SamsungAI/baseline.ipynb#ch0000003?line=3'>4</a> mol = []
#       <a href='vscode-notebook-cell:/Users/dataly/Desktop/Yeongyu/dacon/SamsungAI/baseline.ipynb#ch0000003?line=5'>6</a> for i in tqdm(train[train.columns[0]]):
# ----> <a href='vscode-notebook-cell:/Users/dataly/Desktop/Yeongyu/dacon/SamsungAI/baseline.ipynb#ch0000003?line=6'>7</a>     tmp_g = pd.read_csv(f"g_file/{i}" + '_g.csv')
#       <a href='vscode-notebook-cell:/Users/dataly/Desktop/Yeongyu/dacon/SamsungAI/baseline.ipynb#ch0000003?line=8'>9</a>     if len(tmp_g) >= max_len:
#      <a href='vscode-notebook-cell:/Users/dataly/Desktop/Yeongyu/dacon/SamsungAI/baseline.ipynb#ch0000003?line=9'>10</a>         max_len = len(tmp_g)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'g_file/train_0_g.csv'
